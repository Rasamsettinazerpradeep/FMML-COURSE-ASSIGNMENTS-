# %% [markdown]
# <a href="https://colab.research.google.com/github/Rasamsettinazerpradeep/FMML-COURSE-ASSIGNMENTS-/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 04:52:52--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   208MB/s    in 0.3s
#
# 2023-05-05 04:52:52 (208 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 8981   1803.01937v1  Evaluation of summarization tasks is extremely...    cs
# 19601   1101.2378v1  Performing effective preference-based data ret...    cs
# 20747  1701.02543v1  Forecasting the flow of crowds is of great imp...    cs
# 14260  1501.06241v2  We characterize the performance of sequential ...  stat
# 21900  1502.01425v3  We propose a novel sparse tensor decomposition...  stat
# ...             ...                                                ...   ...
# 11234  1506.01709v1  Preference learning (PL) is a core area of mac...  stat
# 11942  1704.08303v3  In this work a novel method to quantify spectr...  stat
# 14893   1109.4531v1  The relationship between written and spoken wo...    cs
# 1963   1610.00163v2  In this paper we propose cross-modal convoluti...  stat
# 4520    0804.1441v3  This paper focuses on the problem of kernelizi...    cs
#
#                                                    title  year  \
# 8981   ROUGE 2.0: Updated and Improved Measures for E...  2018
# 19601  Extracting Features from Ratings: The Role of ...  2011
# 20747  Predicting Citywide Crowd Flows Using Deep Spa...  2017
# 14260             Sequential Sensing with Model Mismatch  2015
# 21900               Provable Sparse Tensor Decomposition  2015
# ...                                                  ...   ...
# 11234                    The Preference Learning Toolbox  2015
# 11942  Spectral Ergodicity in Deep Learning Architect...  2017
# 14893  A Probabilistic Approach to Pronunciation by A...  2011
# 1963   X-CNN: Cross-modal Convolutional Neural Networ...  2016
# 4520   On Kernelization of Supervised Mahalanobis Dis...  2008
#
#                                                 keywords
# 8981   [evaluation, summarization, extremely, determi...
# 19601  [performing, effective, preference, retrieval,...
# 20747  [forecasting, importance, management, challeng...
# 14260  [characterize, performance, sequential, inform...
# 21900  [decomposition, truncated, incorporates, selec...
# ...                                                  ...
# 11234  [preference, relations, generated, increasing,...
# 11942  [ergodicity, presented, methodology, approache...
# 14893  [relationship, convoluted, languages, orthogra...
# 1963   [convolutional, biologically, architectures, s...
# 4520   [kernelizing, supervised, mahalanobis, followi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 8981     [evaluation, summarization, extremely, determi...
# 19601    [performing, effective, preference, retrieval,...
# 20747    [forecasting, importance, management, challeng...
# 14260    [characterize, performance, sequential, inform...
# 21900    [decomposition, truncated, incorporates, selec...
#                                ...
# 18945    [inference, differentiation, according, multiv...
# 5406     [introduce, embarrassingly, parameter, algorit...
# 31219    [efficient, technique, convolutional, eliminat...
# 26689    [introduce, supervised, adversarial, presented...
# 39616    [automatic, continuous, detection, containing,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8689 words.
# Out of those 4552 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="92ff29fd-c3e4-4419-bd24-ad051f985ca0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92ff29fd-c3e4-4419-bd24-ad051f985ca0")) {                    Plotly.newPlot(                        "92ff29fd-c3e4-4419-bd24-ad051f985ca0",                        [{"x":["introduce","summaries","effective","capturing","synonymous","evaluation","automatic","generated","limitations","summarization","determining","improvements","extremely","evaluating","attributes","performed","meaningful","available","extracted","retrieval","technical","anecdotal","networking","investigation","information","preference","perception","representations","methodology","consideration","preliminary","performing","supporting","particularly","systematically","extracting","collaborative","collection","framework","dynamically","forecasting","microsoft","different","importance","predicting","specifically","properties","collectively","conditions","baselines","aggregate","closeness","management","providing","dependencies","outperforms","challenging","aggregation","monitoring","assigning","extensive","experimental","convolutional","structure","including","developed","sketching","mismatched","initialization","additional","sequential","eigenvectors","efficient","posterior","establish","performance","particular","measurements","eigenvalues","decreasing","characterize","covariance","precision","directions","confirmed","introducing","theoretical","applications","truncation","decomposition","selection","advantages","empirical","guaranteed","incorporates","truncated","dimensional","regressions","iteration","procedure","components","prediction","statistical","significantly","strengthen","estimator","estimation","conducted","simulated","clustering","developers","additionally","inexpensive","competitive","independent","describes","outperform","benchmarks","automated","significant","computationally","recognition","distributed","technique","supervised","classification","synthesized","parallelism","partitions","consistent","objectives","convergence","described","facilitating","stochasticity","stochastic","regularization","decomposed","construction","processes","estimated","uncertainty","improving","simultaneously","inference","variational","parameters","advantage","experimentally","demonstrate","functions","generalization","configurations","discretisation","statistics","resulting","continuous","algorithm","astronomy","modulated","computational","magnitude","approaches","neuroscience","synthetic","translation","gradients","propagate","structural","consequence","experiments","feedforward","contributing","recurrent","analysing","controllable","underlying","political","factorial","remaining","probabilistic","predominantly","preferences","independence","assumptions","elections","literature","assumption","distributions","calculation","smoothness","processing","factorizations","typically","principle","adaptation","confounders","supplement","exponential","submission"],"y":[328,17,235,40,3,270,196,183,72,24,35,123,50,63,65,141,47,307,123,101,30,2,8,29,705,31,33,248,68,20,43,80,20,85,24,59,37,78,569,28,18,14,758,77,76,165,197,6,151,59,25,4,55,84,49,275,292,22,27,17,182,381,387,319,244,196,2,6,26,115,58,4,408,48,56,866,262,59,2,12,41,23,77,50,9,39,144,417,2,71,167,79,151,31,31,7,184,2,32,110,100,217,165,293,5,24,212,72,57,140,17,73,8,116,128,76,105,104,105,245,90,381,85,256,199,478,9,9,13,85,22,112,66,8,0,128,72,12,75,96,46,92,105,101,218,50,215,91,68,575,208,123,23,0,68,155,105,769,3,6,298,55,429,14,123,100,43,6,72,20,594,19,0,139,13,8,95,10,2,31,160,4,35,34,61,4,136,61,105,16,14,296,5,99,58,69,1,3,38,8],"type":"bar"},{"x":["introduce","summaries","effective","capturing","synonymous","evaluation","automati ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4552,), (4552, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7825

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Non</span> <span style=''>linear</span> <span style=''>Learning</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.31958762886597936);'>Statistical</span> <span style=''>Machine</span> <span style='background-color:rgba(0, 255, 0, 0.7241379310344827);'>Translation</span> <br/><br/><span style=''>Modern</span> <span style='background-color:rgba(255, 0, 0, 0.31958762886597936);'>statistical</span> <span style=''>machine</span> <span style='background-color:rgba(0, 255, 0, 0.7241379310344827);'>translation</span> <span style=''>(SMT)</span> <span style=''>systems</span> <span style=''>usually</span> <span style=''>use</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>features</span> <span style=''>to</span> <span style=''>model</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.7241379310344827);'>translation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>The</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>assumes</span> <span style=''>that</span> <span style=''>all</span> <span style=''>the</span> <span style=''>features</span> <span style=''>are</span> <span style=''>in</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>constrains</span> <span style=''>that</span> <span style=''>each</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>interacts</span> <span style=''>with</span> <span style=''>the</span> <span style=''>rest</span> <span style=''>features</span> <span style=''>in</span> <span style=''>an</span> <span style=''>linear</span> <span style=''>manner</span> <span style=''>which</span> <span style=''>might</span> <span style=''>limit</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressive</span> <span style=''>power</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>and</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>a</span> <span style=''>under</span> <span style=''>fit</span> <span style=''>model</span> <span style=''>on</span> <span style=''>the</span> <span style=''>current</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>modeling</span> <span style=''>for</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.7241379310344827);'>translation</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>hypotheses</span> <span style=''>based</span> <span style=''>on</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>more</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.39199999999999996);'>interaction</span> <span style=''>between</span> <span style=''>features</span> <span style=''>A</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>presented</span> <span style=''>for</span> <span style=''>training</span> <span style=''>the</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>We</span> <span style=''>als ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Multiscale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Frequency</span> <span style=''>Data</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiscale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>volatility</span> <span style=''>of</span> <span style=''>an</span> <span style=''>Ito</span> <span style=''>process</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>market</span> <span style=''>microstructure</span> <span style=''>noise</span> <span style=''>(observation</span> <span style=''>error)</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiscale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>process</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequency</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequency</span> <span style=''>and</span> <span style=''>the</span> <span style=''>concept</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiscale</span> <span style=''>ratio</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>to</span> <span style=''>quantify</span> <span style=''>the</span> <span style=''>bias</span> <span style=''>in</span> <span style=''>the</span> <span style=''>realized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>volatility</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>error</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiscale</span> <span style=''>ratio</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>from</span> <span style=''>a</span> <span style=''>single</span> <span style=''>sample</span> <span style=''>path</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequency</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequency</span> <span style=''>bias</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>reduces</span> <span style=''>variance</span> <span style=''>We</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>method</span> <span style=''>to</span> <span style=''>include</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>errors</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>the</span> <span style=''>implied</span> <span style=''>time</span> <span style=''>domain</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Symmetry</span> <span style=''>Saddle</span> <span style=''>Points</span> <span style=''>and</span> <span style=''>Global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Landscape</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6097560975609756);'>Nonconvex</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.37404580152671757);'>Factorization</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style=''>theory</span> <span style=''>for</span> <span style=''>studying</span> <span style=''>the</span> <span style=''>xllandscape</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6097560975609756);'>nonconvex</span> <span style=''>xloptimization</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>symmetric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>tzfor</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>(eg</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.37404580152671757);'>factorization</span> <span style=''>phase</span> <span style='background-color:rgba(0, 255, 0, 0.5905511811023623);'>retrieval</span> <span style=''>and</span> <span style=''>deep</span> <span style=''>linear</span> <span style=''>neural</span> <span style=''>networks)</span> <span style=''>In</span> <span style=''>specific</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.40298507462686567);'>locations</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3684210526315789);'>stationary</span> <span style=''>points</span> <span style=''>and</span> <span style=''>the</span> <span style=''>null</span> <span style=''>space</span> <span style=''>of</span> <span style=''>Hessian</span> <span style=''>matrices</span> <span style=''>xlof</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>via</span> <span style=''>the</span> <span style=''>lens</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariant</span> <span style=''>groupsremovedfor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.37404580152671757);'>factorization</span> <span style=''>phase</span> <span style='background-color:rgba(0, 255, 0, 0.5905511811023623);'>retrieval</span> <span style=''>and</span> <span style=''>deep</span> <span style=''>linear</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>As</span> <span style=''>a</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivating</span> <span style=''>example</span> <span style=''>we</span> <span style=''>apply</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>general</span> <span style=''>theory</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>the</span> <span style=''>global</span> <span style=''>xllandscape</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Adaptation</span> <span style=''>and</span> <span style=''>learning</span> <span style=''>over</span> <span style=''>networks</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>system</span> <span style=''>modeling</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>chapter</span> <span style=''>we</span> <span style=''>analyze</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>problems</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environments</span> <span style=''>eg</span> <span style=''>sensor</span> <span style=''>networks</span> <span style=''>or</span> <span style=''>peer</span> <span style=''>to</span> <span style=''>peer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>protocols</span> <span style=''>In</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scenarios</span> <span style=''>the</span> <span style=''>agents</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>receive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>streaming</span> <span style=''>fashion</span> <span style=''>and</span> <span style=''>they</span> <span style=''>are</span> <span style=''>required</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>a</span> <span style=''>common</span> <span style=''>(nonlinear)</span> <span style=''>model</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternating</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computations</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communications</span> <span style=''>with</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighbors</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinction</span> <span style=''>between</span> <span style=''>single</span> <span style=''>task</span> <span style=''>problems</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>model</span> <span style=''>is</span> <span style=''>common</span> <span style=''>to</span> <span style=''>all</span> <span style=''>agents</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multitask</span> <span style=''>problems</span> <span style=''>where</span> <span style=''>each</span> <span style=''>agent</span> <span style=''>might</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>model</span> <span style=''>due</span> <span style=''>to</span> <span style=''>eg</span> <span style=''>spatial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>or</span> <span style=''>other</span> <span style=''>factors</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Currently</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.1048158640226629)
# 	representation (0.12854107648725213)
# 	segmentation (0.07294617563739376)
# 	knowledge (0.12358356940509915)
# 	challenging (0.10339943342776203)
# 	information (0.2496458923512748)
# 	different (0.26841359773371104)
# 	detection (0.12570821529745044)
# 	recognition (0.13491501416430596)
# 	convolutional (0.13703966005665721)
#
# Some Statistics words are:
# 	convergence (0.12196356275303644)
# 	variables (0.1346153846153846)
# 	estimation (0.17661943319838055)
# 	theoretical (0.1533400809716599)
# 	statistical (0.16194331983805668)
# 	distribution (0.1887651821862348)
# 	inference (0.1938259109311741)
# 	dimensional (0.18572874493927125)
# 	algorithm (0.41346153846153844)
# 	regression (0.1882591093117409)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3bba48d0-f2c6-496f-8dc4-0bcdb5d3c8d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bba48d0-f2c6-496f-8dc4-0bcdb5d3c8d1")) {                    Plotly.newPlot(                        "3bba48d0-f2c6-496f-8dc4-0bcdb5d3c8d1",                        [{"x":["introduce","summaries","effective","capturing","synonymous","evaluation","automatic","generated","limitations","summarization","determining","improvements","extremely","evaluating","attributes","performed","meaningful","available","extracted","retrieval","technical","anecdotal","networking","investigation","information","preference","perception","representations","methodology","consideration","preliminary","performing","supporting","particularly","systematically","extracting","collaborative","collection","framework","dynamically","forecasting","microsoft","different","importance","predicting","specifically","properties","collectively","conditions","baselines","aggregate","closeness","management","providing","dependencies","outperforms","challenging","aggregation","monitoring","assigning","extensive","experimental","convolutional","structure","including","developed","sketching","mismatched","initialization","additional","sequential","eigenvectors","efficient","posterior","establish","performance","particular","measurements","eigenvalues","decreasing","characterize","covariance","precision","directions","confirmed","introducing","theoretical","applications","truncation","decomposition","selection","advantages","empirical","guaranteed","incorporates","truncated","dimensional","regressions","iteration","procedure","components","prediction","statistical","significantly","strengthen","estimator","estimation","conducted","simulated","clustering","developers","additionally","inexpensive","competitive","independent","describes","outperform","benchmarks","automated","significant","computationally","recognition","distributed","technique","supervised","classification","synthesized","parallelism","partitions","consistent","objectives","convergence","described","facilitating","stochasticity","stochastic","regularization","decomposed","construction","processes","estimated","uncertainty","improving","simultaneously","inference","variational","parameters","advantage","experimentally","demonstrate","functions","generalization","configurations","discretisation","statistics","resulting","continuous","algorithm","astronomy","modulated","computational","magnitude","approaches","neuroscience","synthetic","translation","gradients","propagate","structural","consequence","experiments","feedforward","contributing","recurrent","analysing","controllable","underlying","political","factorial","remaining","probabilistic","predominantly","preferences","independence","assumptions","elections","literature","assumption","distributions","calculation","smoothness","processing","factorizations","typically","principle","adaptation","confounders","supplement","exponential","submission","polynomial","complexity","discovery","architectural","mathematical","formulation","flexibility","rendering","considered","adaptively","transforming","architectures","sophistication","generalizes","involving","expensive","community","candidates","potential","measuring","discovered","application","magnitudes","important","predictive","represents","shapelets","therefore","euclidean","algorithms","evaluates","displayed","shortcomings","furthermore","localization","revisited","worldwide","synthesis","annotation","contribute","supported","sophisticated","locations","individual","compositing","controlled","monocular","occlusions","interactions","annotations","associations","variability","minimization","observable","inequality","associated","timest ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	stochasticity
# 	discretisation
# 	contributing
# 	martingales
# 	determinant
# 	tempering
# 	thermostats
# 	distributionally
# 	presupposes
# 	cumulants
# 	gaussianization
# 	detectability
# 	degeneration
# 	minimises
# 	presumably
# 	unspecified
# 	semiparametric
# 	parametrizations
# 	entrywise
# 	collinearity
# Some words which never appear in Statistics papers:
# 	synonymous
# 	anecdotal
# 	shapelets
# 	worldwide
# 	compositing
# 	monocular
# 	occlusions
# 	ambitious
# 	starcraft
# 	withdrawn
# 	chromosomes
# 	metaheuristics
# 	inflection
# 	lemmatization
# 	pioneering
# 	melanocytic
# 	threatening
# 	conceived
# 	navigation
# 	photographs

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.049524274213223e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.725
